# %%
import os, shutil

file_name_list = ["Abstract_Expressionism", "Art_Nouveau_Modern", "Baroque", "Color_Field_Painting", "Cubism", "Early_Renaissance", "Expressionism", "Fauvism", "High_Renaissance", "Impressionism", "Mannerism_Late_Renaissance", "Minimalism", "Naive_Art_Primitivism", "Northern_Renaissance", "Pop_Art", "Post_Impressionism", "Realism", "Rococo", "Romanticism", "Ukiyo_e"]

# %%
path = "/content/drive/My Drive/Colab Notebooks/wikiart/test/Cubism/Synthetic_Cubism/"
target = "/content/drive/My Drive/Colab Notebooks/wikiart/test/Cubism/"

# %%
files = os.listdir(path)

# %%
for x in files:
  shutil.move(path+x, target+x)
  print(x +" success")

# %%
len(files)
# Out:
# 216

# %%
path = "/content/drive/My Drive/Colab Notebooks/wikiart/content reference/"

# %%
# detect abnormal files

for style in file_name_list:
  for x2 in file_name_list:
    if not (style == x2):
      unique = path+style+"/"+style+"|"+x2
      x = len(os.listdir(unique))
      if x == 0:
        print(unique+"HELP!!")
# Out:
# /content/drive/My Drive/Colab Notebooks/wikiart/content reference/Impressionism/Impressionism|Abstract_ExpressionismHELP!!
# /content/drive/My Drive/Colab Notebooks/wikiart/content reference/Realism/Realism|Abstract_ExpressionismHELP!!
